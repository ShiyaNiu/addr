# %%
import tensorflow as tf

# %%
vocab = ["a", "b", "c", "d"]
data = tf.constant([["a", "c", "d"], ["d", "z", "b"]])
layer = tf.keras.layers.StringLookup(vocabulary=vocab)
vectorized_data = layer(data)
print(vectorized_data)
print(layer.get_vocabulary())
# Out:
# tf.Tensor(
# [[1 3 4]
#  [4 0 2]], shape=(2, 3), dtype=int64)
# ['[UNK]', 'a', 'b', 'c', 'd']

# %%
text_dataset = tf.data.Dataset.from_tensor_slices(["foo", "bar", "baz"])
max_features = 5000  # Maximum vocab size.
max_len = 4  # Sequence length to pad the outputs to.

# Create the layer.
vectorize_layer = tf.keras.layers.TextVectorization(
 max_tokens=max_features,
 output_mode='int',
 output_sequence_length=max_len)

# Now that the vocab layer has been created, call `adapt` on the
# text-only dataset to create the vocabulary. You don't have to batch,
# but for large datasets this means we're not keeping spare copies of
# the dataset.
vectorize_layer.adapt(text_dataset.batch(64))

# Create the model that uses the vectorize text layer

# Start by creating an explicit input layer. It needs to have a shape of
# (1,) (because we need to guarantee that there is exactly one string
# input per batch), and the dtype needs to be 'string'.
model = tf.keras.models.Sequential()
model.add(tf.keras.Input(shape=(1,), dtype=tf.string))
model.add(vectorize_layer)
# The first layer in our model is the vectorization layer. After this
# layer, we have a tensor of shape (batch_size, max_len) containing
# vocab indices.
model.add(vectorize_layer)

# Now, the model can map strings to integers, and you can add an
# embedding layer to map these integers to learned embeddings.
input_data = [["foo qux bar"], ["qux baz"]]
model.predict(input_data)
print(vectorize_layer.get_vocabulary())
# Out:
# 1/1 [==============================] - 0s 92ms/step
# ['', '[UNK]', 'foo', 'baz', 'bar']

# %%
import os
import json
import tensorflow as tf
import numpy as np

# %%
def load_vocabs(save_dir, filename='vocabs.json'):
    with open(os.path.join(save_dir,filename),'r',encoding="utf-8") as file:
        vocab = json.load(file)
        text_vocab = vocab["word_vocab"]["idx_to_token"]
        label_vocab = vocab["tag_vocab"]["idx_to_token"]
        return text_vocab,label_vocab
save_dir = "../data/tianchi/"
text_vocab,label_vocab = load_vocabs(save_dir, filename='vocabs.json')
vectorize_layer = tf.keras.layers.TextVectorization(
 standardize=None,
 output_mode='int',
 vocabulary=text_vocab)
vectorize_layer_2 = tf.keras.layers.TextVectorization(
 standardize=None,
 output_mode='int',
 vocabulary=label_vocab)
# Because we've passed the vocabulary directly, we don't need to adapt
# the layer - the vocabulary is already set. The vocabulary contains the
# padding token ('') and OOV token ('[UNK]') as well as the passed
# tokens.
print(vectorize_layer.get_vocabulary())
print(vectorize_layer_2.get_vocabulary())
# Out:
# ['', '[UNK]', '浙', '江', '杭', '州', '市', '干', '区', '九', '堡', '镇', '三', '村', '一', '省', '温', '平', '阳', '县', '海', '西', '宋', '埠', '公', '园', '南', '路', '0', '号', '余', '姚', '模', '具', '城', '金', '型', '_', '样', '红', 'A', '打', '印', '白', '杨', '街', '道', '下', '沙', '开', '发', '世', '茂', '滨', '花', '峻', '景', '湾', '幢', '秋', '菱', '兰', '溪', '立', '达', '框', '业', '有', '限', '司', '湖', '中', '环', '和', '交', '叉', '口', '嘉', '兴', '乡', '规', '划', '建', '设', '管', '理', '委', '员', '会', '关', '士', '伯', '大', '龙', '泉', '组', '团', '物', '处', '火', '车', '站', '旧', '家', '属', '石', '转', '单', '身', '宿', '舍', '对', '面', '安', '宜', '田', '百', '合', '栋', '义', '乌', '长', '春', '二', '楼', '教', '务', '科', '华', '永', '康', '方', '岩', '文', '万', '里', '绍', '袍', '工', '纪', '跟', '汤', '苏', '泊', '尔', '厂', '房', '仓', '库', '上', '徐', '汇', '宛', '弄', '佳', '寓', '港', '清', '远', '-', '丹', '临', '山', '当', '色', '宁', '波', '东', '丁', '浦', '周', '邓', '振', '莱', '斜', '回', '巴', '黎', '附', '近', '武', '太', '洋', '国', '际', '货', '运', '代', '徽', '宣', '广', '德', '巨', '朝', '办', '元', '桐', '门', '育', '才', '心', '卫', '生', '院', '鹿', '解', '放', '正', '厦', '乐', '场', '凤', '凰', '尚', '品', '五', '福', '小', '濮', '凯', '旋', '电', '联', '汽', '商', '后', '曙', '光', '饿', '了', '么', '迎', '新', '动', '力', '漫', '庭', '欣', '阁', '贸', '北', '政', '府', '接', '待', '室', '期', '高', '端', '优', '增', '篁', '疆', '阿', '拉', '局', '刑', '事', '侦', '查', '队', '巷', '六', '半', '农', '银', '行', '支', '颐', '数', '码', '柳', '青', '朱', '晶', '都', '鄞', '古', '林', '礼', '桥', '丰', '盛', '拱', '墅', '谭', '泰', '购', '瓯', '服', '装', '展', '罗', '塘', '沿', '仙', '稠', '通', '缘', '化', '览', '苑', '前', '虞', '天', '胜', '四', '不', '用', '台', '居', '耕', '慈', '逍', '黄', '姑', '技', '靖', '姜', '胡', '坟', '杜', '莫', '明', '智', '测', '绘', '层', '泽', '雅', '仑', '衙', '纬', '铜', '店', '椒', '名', '经', '济', '选', '雨', '香', '樟', '树', '堤', '应', '社', '晨', '曦', '复', '人', '资', '源', '产', '杠', '梧', '基', '地', '迪', '诸', '暨', '艮', '塔', '舟', '沈', '廿', '陵', '体', '草', '横', '畈', '舒', '坊', '蕉', '内', '岭', '馆', '头', '宗', '汉', '两', '蔡', '紫', '校', '庐', '其', '他', '阆', '鑫', '桂', '盐', '之', '老', '瑞', '格', '酒', '深', '圳', '宝', '井', '保', '揭', '普', '爱', '苗', '幼', '儿', '植', '入', '米', '越', '釜', '磨', '吉', '利', '尖', '闻', '澜', '辖', '织', '河', '洞', '凌', '旗', '艺', '川', '成', '驿', '悦', '魏', '旺', '你', '手', '套', '点', '兵', '星', '质', '检', '旭', '日', '孙', '学', '霞', '吴', '派', '宠', '雪', '沁', '娄', '豪', '土', '贵', '谢', '某', '收', '璜', '融', '全', '无', '强', '机', '信', '侨', '饭', '水', '自', '季', '宅', '观', '师', '璞', '净', '警', '座', '吐', '鲁', '番', '托', '克', '逊', '友', '好', '所', '芳', '龄', '美', '容', '晓', '多', '翠', '云', '哈', '尼', '族', '彝', '治', '个', '七', '旁', '十', '贝', '斯', '双', '赞', '丽', '风', '珠', '秀', '峰', '涛', '穗', '崇', '延', '供', '销', '超', '总', '潮', '饶', '洲', '女', '衢', '圣', '械', '八', '狮', '晗', '望', '神', '编', '第', '功', '能', '塞', '萧', '英', '木', '器', '钱', '进', '游', '泳', '池', '浮', '楠', '嵊', '留', '灵', '屋', '虎', '恒', '邹', '边', '善', '子', '苍', '绿', '岛', '定', '漳', '亭', '舫', '共', '月', '骆', '玉', '宾', '梁', '润', '陆', '浜', '堂', '奶', '茶', '圩', '角', '晴', '民', '闸', '漓', '渚', '特', '陶', '瓷', '鹏', '轩', '修', '音', '驼', '祥', '符', '纺', '付', '创', '箱', '包', '术', '堰', '王', '仁', '宏', '芝', '柯', '流', '歌', '甑', '芯', '坛', '赤', '果', '啊', '讯', '夹', '屿', '荼', '领', '医', '阀', '张', '陈', '线', '法', '栖', '界', '绪', '同', '帆', '锁', '岸', '富', '寺', '侧', '睦', '萍', '腔', '财', '步', '岗', '莲', '潘', '语', '象', '原', '铺', '阵', '坂', '与', '顺', '松', '部', '震', '凉', '幸', '便', '俞', '范', '塑', '状', '集', '甬', '书', '益', '汝', '霖', '思', '棠', '左', '森', '专', '营', '鞋', '块', '陀', '住', '薪', '禾', '屠', '甸', '狄', '奥', '备', '脑', '京', '故', '庄', '球', '的', '眼', '镜', '叶', '岙', '知', '祺', '碧', '意', '玖', '铭', '告', '锡', '峨', '眉', '绥', '佛', '姆', '蕲', '檀', '洪', '卖', '马', '珊', '瑚', '比', '萨', '闵', '时', '捷', '积', '先', '辉', '段', '重', '庆', '巫', '掌', '起', '材', '舜', '疗', '孵', '颡', '孟', '快', '递', '寿', '昌', '梅', '视', '域', '导', '向', '浅', '桃', '围', '莘', '塍', '吕', '薛', '健', '料', '渡', '诊', '御', '精', '鸿', '渊', '葛', '航', '魅', '梦', '琴', '嵩', '如', '皋', '怡', '年', '闽', '食', '钟', '盈', '锐', '湘', '荆', '涨', '常', '熟', '招', '刘', '坝', '庙', '腾', '蛟', '巢', '底', '惠', '博', '李', '陇', '贤', '童', '菜', '孔', '婺', '垅', '首', '外', '郭', '翔', '众', ' ...
# ['', '[UNK]', 'I-poi', 'S-poi', 'I-road', 'B-subpoi', 'S-assist', 'I-prov', 'E-prov', 'I-community', 'E-devzone', 'E-village_group', 'B-cellno', 'B-village_group', 'B-intersection', 'I-roadno', 'E-community', 'B-roadno', 'I-village_group', 'B-floorno', 'E-floorno', 'B-devzone', 'I-distance', 'B-distance', 'B-assist', 'E-cellno', 'B-district', 'E-houseno', 'I-city', 'I-floorno', 'I-intersection', 'B-community', 'I-houseno', 'B-road', 'B-town', 'B-houseno', 'O', 'S-intersection', 'E-city', 'I-subpoi', 'I-cellno', 'I-devzone', 'B-city', 'B-poi', 'E-distance', 'E-road', 'E-assist', 'S-community', 'E-subpoi', 'E-intersection', 'I-district', 'E-town', 'S-district', 'I-town', 'I-assist', 'B-prov', 'E-district', 'E-roadno', 'E-poi']

# %%
print(vectorize_layer.vocabulary_size())
print(vectorize_layer_2.vocabulary_size())
# Out:
# 2438
# 59

# %%
text = tf.expand_dims(tf.constant([" ".join(['als','浙', '江', '杭', "skdk", '区', '九'])," ".join(['九', '堡', '镇', '三', '村'])]),-1)
label = tf.expand_dims(tf.constant([" ".join(['I', ''])," ".join(['I-poi', 'S-poi'])]),-1)

print(vectorize_layer(text))
print(vectorize_layer_2(label))
# Out:
# tf.Tensor(
# [[ 1  2  3  4  1  8  9]
#  [ 9 10 11 12 13  0  0]], shape=(2, 7), dtype=int64)
# tf.Tensor(
# [[1 0]
#  [2 3]], shape=(2, 2), dtype=int64)

# %%
pred = np.random.random(size=(2,4,5))
print(pred)
# Out:
# [[[0.29593048 0.75991131 0.66691184 0.0442313  0.0660399 ]
#   [0.31933673 0.83671252 0.93205941 0.69007656 0.84742818]
#   [0.44058372 0.1588558  0.40864148 0.77324524 0.15715588]
#   [0.88978617 0.85390921 0.44435366 0.93024436 0.1051121 ]]
#
#  [[0.74604873 0.00524921 0.99680777 0.58359923 0.29062825]
#   [0.1658304  0.52366239 0.74503509 0.32150467 0.68321395]
#   [0.76674803 0.01045743 0.84811724 0.12360591 0.86196348]
#   [0.3819387  0.64659708 0.7773225  0.10516274 0.95523952]]]

# %%
pred = tf.cast(pred,tf.float32)

# %%
a = tf.constant(12, dtype=tf.int32)
print(a)
print(a.numpy())
# Out:
# tf.Tensor(12, shape=(), dtype=int32)
# 12

# %%
tp = {"1":tf.constant(1,dtype=tf.int32),"2":tf.constant(1,dtype=tf.int32),"3":tf.constant(1,dtype=tf.int32)}
out = list(map(lambda x:x.numpy(),list(tp.values())))

# %%
out
# Out:
# [1, 1, 1]
